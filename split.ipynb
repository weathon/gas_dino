# %%
datasets_tr = {
    0: {'baseline':['highway', 'pedestrians', 'office', 'PETS2006'],
        'cameraJitter':['badminton', 'traffic', 'boulevard', 'sidewalk'],
        'badWeather':['skating', 'blizzard', 'snowFall', 'wetSnow'],
        'dynamicBackground':['boats', 'canoe', 'fall', 'fountain01', 'fountain02', 'overpass'],
        'intermittentObjectMotion':['abandonedBox', 'parking', 'sofa', 'streetLight', 'tramstop', 'winterDriveway'],
        'lowFramerate':['port_0_17fps', 'tramCrossroad_1fps', 'tunnelExit_0_35fps', 'turnpike_0_5fps'],
        'nightVideos':['bridgeEntry', 'busyBoulvard', 'fluidHighway', 'streetCornerAtNight', 'tramStation', 'winterStreet'],
        'PTZ':['continuousPan', 'intermittentPan', 'twoPositionPTZCam', 'zoomInZoomOut'],
        'shadow':['backdoor', 'bungalows', 'busStation', 'copyMachine', 'cubicle', 'peopleInShade'],
        'thermal':['corridor', 'diningRoom', 'lakeSide', 'library', 'park'],
        'turbulence':['turbulence0', 'turbulence1', 'turbulence2', 'turbulence3']
        }, # Full dataset
    1: {'baseline':['pedestrians', 'office', 'PETS2006'],
        'cameraJitter':['traffic', 'boulevard', 'sidewalk'],
        'badWeather':['skating', 'snowFall', 'wetSnow'],
        'dynamicBackground':['boats', 'canoe', 'fall', 'fountain01'],
        'intermittentObjectMotion':['abandonedBox', 'parking', 'streetLight', 'tramstop', 'winterDriveway'],
        'lowFramerate':['tramCrossroad_1fps', 'tunnelExit_0_35fps', 'turnpike_0_5fps'],
        'nightVideos':['fluidHighway', 'streetCornerAtNight', 'tramStation', 'winterStreet'],
        'PTZ':['intermittentPan', 'twoPositionPTZCam', 'zoomInZoomOut'],
        'shadow':['backdoor', 'bungalows', 'busStation', 'cubicle', 'peopleInShade'],
        'thermal':['diningRoom', 'library', 'park'],
        'turbulence':['turbulence1', 'turbulence2', 'turbulence3']
        }, # CV fold 1
    2: {'baseline':['highway', 'office', 'PETS2006'],
        'cameraJitter':['badminton', 'boulevard', 'sidewalk'],
        'badWeather':['blizzard', 'snowFall', 'wetSnow'],
        'dynamicBackground':['canoe', 'fall', 'fountain02', 'overpass'],
        'intermittentObjectMotion':['abandonedBox', 'parking', 'sofa', 'streetLight', 'tramstop'],
        'lowFramerate':['port_0_17fps', 'tunnelExit_0_35fps', 'turnpike_0_5fps'],
        'nightVideos':['bridgeEntry', 'busyBoulvard', 'fluidHighway', 'streetCornerAtNight'],
        'PTZ':['continuousPan', 'twoPositionPTZCam', 'zoomInZoomOut'],
        'shadow':['backdoor', 'bungalows', 'copyMachine', 'cubicle', 'peopleInShade'],
        'thermal':['corridor', 'diningRoom', 'lakeSide', 'park'],
        'turbulence':['turbulence0', 'turbulence2', 'turbulence3']
        }, # CV fold 2
    3: {'baseline':['highway', 'pedestrians', 'PETS2006'],
        'cameraJitter':['badminton', 'traffic', 'sidewalk'],
        'badWeather':['skating', 'blizzard', 'snowFall'],
        'dynamicBackground':['boats', 'fall', 'fountain01', 'fountain02', 'overpass'],
        'intermittentObjectMotion':['sofa', 'streetLight', 'tramstop', 'winterDriveway'],
        'lowFramerate':['port_0_17fps', 'tramCrossroad_1fps', 'turnpike_0_5fps'],
        'nightVideos':['bridgeEntry', 'busyBoulvard', 'streetCornerAtNight', 'tramStation', 'winterStreet'],
        'PTZ':['continuousPan', 'intermittentPan', 'twoPositionPTZCam'],
        'shadow':['backdoor', 'bungalows', 'busStation', 'copyMachine'],
        'thermal':['corridor', 'lakeSide', 'library', 'park'],
        'turbulence':['turbulence0', 'turbulence1', 'turbulence3']
        }, # CV fold 3
    4: {'baseline':['highway', 'pedestrians', 'office'],
        'cameraJitter':['badminton', 'traffic', 'boulevard'],
        'badWeather':['skating', 'blizzard', 'wetSnow'],
        'dynamicBackground':['boats', 'canoe', 'fountain01', 'fountain02', 'overpass'],
        'intermittentObjectMotion':['abandonedBox', 'parking', 'sofa', 'winterDriveway'],
        'lowFramerate':['port_0_17fps', 'tramCrossroad_1fps', 'tunnelExit_0_35fps'],
        'nightVideos':['bridgeEntry', 'busyBoulvard', 'fluidHighway', 'tramStation', 'winterStreet'],
        'PTZ':['continuousPan', 'intermittentPan', 'zoomInZoomOut'],
        'shadow':['busStation', 'copyMachine', 'cubicle', 'peopleInShade'],
        'thermal':['corridor', 'diningRoom', 'lakeSide', 'library'],
        'turbulence':['turbulence0', 'turbulence1', 'turbulence2']
        }, # CV fold 4
    5: {'baseline':['pedestrians', 'office', 'PETS2006'],
        'intermittentObjectMotion':['abandonedBox'],
        }, # small dataset for quick debugging
}

datasets_test = {
    1: {'baseline':['highway'],
        'cameraJitter':['badminton'],
        'badWeather':[ 'blizzard'],
        'dynamicBackground':['fountain02', 'overpass'],
        'intermittentObjectMotion':['sofa'],
        'lowFramerate':['port_0_17fps'],
        'nightVideos':['bridgeEntry', 'busyBoulvard'],
        'PTZ':['continuousPan'],
        'shadow':['copyMachine'],
        'thermal':['corridor', 'lakeSide',],
        'turbulence':['turbulence0']
        },
    2: {'baseline':['pedestrians'],
        'cameraJitter':['traffic'],
        'badWeather':['skating'],
        'dynamicBackground':['boats', 'fountain01'],
        'intermittentObjectMotion':['winterDriveway'],
        'lowFramerate':['tramCrossroad_1fps'],
        'nightVideos':['tramStation', 'winterStreet'],
        'PTZ':['intermittentPan'],
        'shadow':['busStation'],
        'thermal':['library'],
        'turbulence':['turbulence1']
        },
    3: {'baseline':['office'],
        'cameraJitter':['boulevard'],
        'badWeather':['wetSnow'],
        'dynamicBackground':['canoe'],
        'intermittentObjectMotion':['abandonedBox', 'parking'],
        'lowFramerate':['tunnelExit_0_35fps'],
        'nightVideos':['fluidHighway'],
        'PTZ':['zoomInZoomOut'],
        'shadow':['cubicle', 'peopleInShade'],
        'thermal':['diningRoom'],
        'turbulence':['turbulence2']
        },
    4: {'baseline':['PETS2006'],
        'cameraJitter':['sidewalk'],
        'badWeather':['snowFall'],
        'dynamicBackground':['fall'],
        'intermittentObjectMotion':['streetLight', 'tramstop'],
        'lowFramerate':['turnpike_0_5fps'],
        'nightVideos':['streetCornerAtNight'],
        'PTZ':['twoPositionPTZCam'],
        'shadow':['backdoor', 'bungalows'],
        'thermal':['park'],
        'turbulence':['turbulence3']
        },
    5: {'baseline':['highway'],
        },
}

# %%
import os
split = 1
train = datasets_tr[split]
test = datasets_test[split]

files_all = os.listdir("/home/wg25r/fastdata/CDNet/in")

train_files = []
for k, v in train.items():
    cat = k
    for dataset in v: 
        for file in files_all:
            if f"{cat}_{dataset}" in file:
                train_files.append(file)

test_files = []
for k, v in test.items():
    cat = k
    for dataset in v: 
        for file in files_all:
            if f"{cat}_{dataset}" in file:
                test_files.append(file)

assert set(train_files).isdisjoint(set(test_files))
assert set(train_files).intersection(set(test_files)) == set()
# overlap error because ending \n?
with open("/home/wg25r/fastdata/CDNet/train.txt", "w") as f:
    f.write("\n".join(train_files))

with open("/home/wg25r/fastdata/CDNet/val.txt", "w") as f:
    f.write("\n".join(test_files))

# %%
with open(f"/home/wg25r/fastdata/CDNet/train.txt") as f:
    train_ = f.read().split("\n") 

with open(f"/home/wg25r/fastdata/CDNet/val.txt") as f:
    val_ = f.read().split("\n") 

assert set(train_).intersection(set(val_)) == set(), "Train and Val overlap: " + str(set(train_).intersection(set(val_)))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[18], line 7
#       4 with open(f"/home/wg25r/fastdata/CDNet/val.txt") as f:
#       5     val_ = f.read().split("\n")
# ----> 7 assert set(train_).intersection(set(val_)) == set(), "Train and Val overlap: " + str(set(train_).intersection(set(val_)))
#
# AssertionError: Train and Val overlap: {'dynamicBackground_boats_in007998.jpg', 'dynamicBackground_boats_in004463.jpg', 'dynamicBackground_boats_in007542.jpg', 'dynamicBackground_boats_in007225.jpg', 'dynamicBackground_boats_in007371.jpg', 'dynamicBackground_boats_in004163.jpg', 'dynamicBackground_boats_in005044.jpg', 'PTZ_intermittentPan_in001715.jpg', 'badWeather_wetSnow_in001709.jpg', 'dynamicBackground_boats_in006993.jpg', 'dynamicBackground_boats_in006247.jpg', 'badWeather_wetSnow_in001687.jpg', 'badWeather_wetSnow_in001068.jpg', 'dynamicBackground_boats_in003293.jpg', 'PTZ_intermittentPan_in001721.jpg', 'dynamicBackground_boats_in005660.jpg', 'dynamicBackground_boats_in003897.jpg', 'dynamicBackground_boats_in003361.jpg', 'dynamicBackground_boats_in004196.jpg', 'dynamicBackground_boats_in007463.jpg', 'badWeather_wetSnow_in000668.jpg', 'dynamicBackground_boats_in002457.jpg', 'dynamicBackground_boats_in004425.jpg', 'dynamicBackground_boats_in003524.jpg', 'dynamicBackground_boats_in006817.jpg', 'dynamicBackground_boats_in004793.jpg', 'dynamicBackground_boats_in004328.jpg', 'badWeather_wetSnow_in000691.jpg', 'dynamicBackground_boats_in002737.jpg', 'dynamicBackground_boats_in004044.jpg', 'dynamicBackground_boats_in005420.jpg', 'dynamicBackground_boats_in005348.jpg', 'badWeather_wetSnow_in001327.jpg', 'dynamicBackground_boats_in007681.jpg', 'dynamicBackground_boats_in004903.jpg', 'dynamicBackground_boats_in007485.jpg', 'dynamicBackground_boats_in005056.jpg', 'PTZ_intermittentPan_in001794.jpg', 'badWeather_wetSnow_in000931.jpg', 'PTZ_intermittentPan_in001992.jpg', 'dynamicBackground_boats_in002576.jpg', 'dynamicBackground_boats_in006588.jpg', 'dynamicBackground_boats_in006132.jpg', 'badWeather_wetSnow_in000853.jpg', 'dynamicBackground_boats_in004612.jpg', 'dynamicBackground_boats_in006477.jpg', 'PTZ_intermittentPan_in002190.jpg', 'dynamicBackground_boats_in002091.jpg', 'dynamicBackground_boats_in006580.jpg', 'dynamicBackground_boats_in005711.jpg', 'badWeather_wetSnow_in000576.jpg', 'dynamicBackground_boats_in007488.jpg', 'dynamicBackground_boats_in005347.jpg', 'dynamicBackground_boats_in003188.jpg', 'PTZ_intermittentPan_in001629.jpg', 'dynamicBackground_boats_in005992.jpg', 'dynamicBackground_boats_in007329.jpg', 'dynamicBackground_boats_in007564.jpg', 'dynamicBackground_boats_in006771.jpg', 'dynamicBackground_boats_in004925.jpg', 'dynamicBackground_boats_in005671.jpg', 'dynamicBackground_boats_in003249.jpg', 'dynamicBackground_boats_in004759.jpg', 'dynamicBackground_boats_in002681.jpg', 'PTZ_intermittentPan_in001433.jpg', 'dynamicBackground_boats_in002883.jpg', 'dynamicBackground_boats_in007777.jpg', 'dynamicBackground_boats_in003464.jpg', 'dynamicBackground_boats_in004999.jpg', 'dynamicBackground_boats_in004253.jpg', 'dynamicBackground_boats_in005425.jpg', 'PTZ_intermittentPan_in002225.jpg', 'dynamicBackground_boats_in007010.jpg', 'dynamicBackground_boats_in006820.jpg', 'dynamicBackground_boats_in002199.jpg', 'badWeather_wetSnow_in001766.jpg', 'dynamicBackground_boats_in006113.jpg', 'dynamicBackground_boats_in004909.jpg', 'dynamicBackground_boats_in007383.jpg', 'PTZ_intermittentPan_in002010.jpg', 'dynamicBackground_boats_in006777.jpg', 'badWeather_wetSnow_in000746.jpg', 'dynamicBackground_boats_in007635.jpg', 'dynamicBackground_boats_in006036.jpg', 'dynamicBackground_boats_in005785.jpg', 'dynamicBackground_boats_in004343.jpg', 'badWeather_wetSnow_in001371.jpg', 'dynamicBackground_boats_in007438.jpg', 'badWeather_wetSnow_in001077.jpg', 'dynamicBackground_boats_in006042.jpg', 'badWeather_wetSnow_in000560.jpg', 'dynamicBackground_boats_in005710.jpg', 'dynamicBackground_boats_in002196.jpg', 'dynamicBackground_boats_in005585.jpg', 'dynamicBackground_boats_in005222.jpg', 'dynamicBackground_boats_in004967.jpg', 'badWeather_wetSnow_in000719.jpg', 'dynamicBackground_boats_in003499.jpg', 'PTZ_intermittentPan_in002043.jpg', 'PTZ_intermittentPan_in001652.jpg', 'badWeather_wetSnow_in001263.jpg', 'dynamicBackground_boats_in005168.jpg', 'dyn ...
